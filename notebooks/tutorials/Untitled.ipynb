# %%
import numpy as np
import matplotlib.pyplot as plt

from ripser import ripser
from persim import plot_diagrams

import circle_bundles as cb
from circle_bundles.bundle2 import Bundle

# %%
r_min, r_max = 0.25, 1.5   #min and max fiber radius
r_func = cb.small_to_big(r_min, r_max)

rng = np.random.default_rng(0)

n_samples = 5000
data, base_points, true_fiber_angles = cb.sample_C2_torus(
    n_samples,
    r_func=r_func,
    sigma=0.15,              
    rng=rng,
    return_alpha=True,
)


#Cover construction
n_landmarks = 30
lmk_angs = np.linspace(0, 2*np.pi, n_landmarks, endpoint= False)
landmarks = np.array([np.cos(lmk_angs), np.sin(lmk_angs)]).T
overlap = 1.99
radius = overlap* np.pi/n_landmarks

cover = cb.MetricBallCover(base_points, landmarks, radius, metric = cb.S1UnitVectorMetric())
cover_data = cover.build()
#Cover construction
bundle = Bundle(U = cover.U, X = data)

# %%
summ = bundle.summary()

# %%
triv_result = bundle.get_local_trivs()
# Out:
# $\displaystyle \begin{aligned}\textbf{Local Trivialization Summary} & \\[6pt]\quad \text{Trivialization error} &:\quad \varepsilon_{\text{triv}} := \sup_{(j\,k)\in\mathcal{N}(\mathcal{U})}\sup_{x\in\pi^{-1}(U_j\cap U_k)} d_{\mathbb{C}}(\Omega_{jk}f_k(x),f_j(x)) = 0.211\ \left(\varepsilon_{\text{triv}}^{\text{geo}}=0.067\pi\right)\\[3pt]\quad \text{Mean triv error} &:\quad \bar{\varepsilon}_{\text{triv}} = 0.033\ \left(\bar{\varepsilon}_{\text{triv}}^{\text{geo}}=0.010\pi\right)\\[3pt]\quad \text{Surjectivity defect} &:\quad \delta := \sup_{(i\,j\,k)\in\mathcal{N}(\mathcal{U})}\min_{v\in\{i,j,k\}} d_H\!\left(f_v(\pi^{-1}(U_i\cap U_j\cap U_k)),\mathbb{S}^1\right) = 0.000\\[3pt]\quad \text{Stability ratio} &:\quad \alpha := \varepsilon_{\text{triv}}/(1-\delta) = 0.211\\[3pt]\quad \text{Cocycle error} &:\quad \varepsilon_{\mathrm{coc}} := \sup_{(i\,j\,k)\in\mathcal{N}(\mathcal{U})}\left\|\Omega_{ij}\Omega_{jk}\Omega_{ki}-I\right\|_F = 0.000\end{aligned}$

# %%
class_result = bundle.get_classes()
# Out:
# $\displaystyle \begin{aligned}\textbf{Characteristic Classes} & \\[6pt]\quad \text{Stiefel--Whitney} &:\quad w_1 = 0\ (\text{orientable})\\[3pt]\quad \text{Euler class} &:\quad e = 0\ (\text{trivial})\\[3pt]\quad \text{Euler rounding dist.} &:\quad d_\infty(\delta\theta, e) = 0\end{aligned}$
# <div style='height:12pt'></div>
# $\displaystyle \textbf{Class Persistence}$
# $\displaystyle \begin{array}{lrrrrr}\textbf{Stage} & k & r & |W_r^{(1)}| & |W_r^{(2)}| & |W_r^{(3)}| \\ \hline \text{Full nerve} & 0 & \infty & 30 & 0 & 0 \\ \text{w₁ cobirth} & 0 & \infty & 30 & 0 & 0 \\ \text{w₁ codeath} & 0 & \infty & 30 & 0 & 0 \\ \text{Euler cobirth} & 0 & \infty & 30 & 0 & 0 \\ \text{Euler codeath} & 0 & \infty & 30 & 0 & 0\end{array}$

# %%
F = bundle.get_global_trivialization(pou = cover.pou)

# %%
map_result = bundle.get_bundle_map(show_summary = True, pou = cover.pou)
# Out:
# $\displaystyle \begin{aligned}\textbf{Bundle Map} & \\[6pt]\quad \text{Cocycle projection dist.} &:\quad d_{\infty}(\Omega,\Pi(\Omega)):=\sup_{(jk)\in\mathcal{N}(\mathcal{U})}\sup_{b\in U_j\cap U_k}\ \|\Omega_{jk}-\Pi(\Omega)_{jk}(b)\|_{F} = 0.000\\[3pt]\quad \text{Trivialization error} &:\quad \varepsilon_{\mathrm{triv}}:=\sup_{(jk)\in\mathcal{N}(\mathcal{U})}\sup_{b\in U_j\cap U_k}\ d_{\mathbb{C}}\!\left(f_j(x),\ \Pi(\Omega)_{jk}(b)f_k(x)\right) = 0.211\ \ (\varepsilon_{\mathrm{triv}}^{\mathrm{geo}} = 0.067\pi)\\[3pt]\quad \text{Mean triv error} &:\quad \bar{\varepsilon}_{\mathrm{triv}} = 0.033\ \ (\bar{\varepsilon}_{\mathrm{triv}}^{\mathrm{geo}} = 0.010\pi)\\[3pt]\quad \text{Grassmann proj. dist.} &:\quad d_{\mathrm{Gr}}:=\sup_{b\in \cup_{U_j\in\mathcal{U}}U_j}\ \left\|\operatorname{sym}(C(b))-\Pi_{\mathrm{Gr}}(C(b))\right\|_F = 0.000\\[3pt]\quad \text{Stiefel proj. dist.} &:\quad d_{\mathrm{St}}:=\sup_{U_j\in\mathcal{U}}\sup_{b\in U_j}\ \left\|\Pi_{\mathrm{St}}\!\big(\Phi_j(b)\big)-\Phi_j(b)\right\|_F = 0.000\\[3pt]\quad \text{Chart disagreement} &:\quad \Delta:=\sup_{(jk)\in\mathcal{N}(\mathcal{U})}\sup_{b\in U_j\cap U_k}\ \|F_j(b)-F_k(b)\|_2 = 0.000\\[3pt]\quad \text{Frame packing} &:\quad \texttt{coloring2}\quad (K=3)\\[3pt]\quad \text{Ambient dimension} &:\quad 6\end{aligned}$

# %%
print(map_result.F.shape)
# Out:
# (5000, 6)

# %%
#Construct a pullback bundle
pullback_data = np.concatenate((base_points, map_result.F), axis = 1)

pullback_bundle = Bundle(U = cover.U, X = pullback_data)

pb_triv_result = bundle.get_local_trivs()
pb_class_result = bundle.get_classes()
# Out:
# $\displaystyle \begin{aligned}\textbf{Local Trivialization Summary} & \\[6pt]\quad \text{Trivialization error} &:\quad \varepsilon_{\text{triv}} := \sup_{(j\,k)\in\mathcal{N}(\mathcal{U})}\sup_{x\in\pi^{-1}(U_j\cap U_k)} d_{\mathbb{C}}(\Omega_{jk}f_k(x),f_j(x)) = 0.211\ \left(\varepsilon_{\text{triv}}^{\text{geo}}=0.067\pi\right)\\[3pt]\quad \text{Mean triv error} &:\quad \bar{\varepsilon}_{\text{triv}} = 0.033\ \left(\bar{\varepsilon}_{\text{triv}}^{\text{geo}}=0.010\pi\right)\\[3pt]\quad \text{Surjectivity defect} &:\quad \delta := \sup_{(i\,j\,k)\in\mathcal{N}(\mathcal{U})}\min_{v\in\{i,j,k\}} d_H\!\left(f_v(\pi^{-1}(U_i\cap U_j\cap U_k)),\mathbb{S}^1\right) = 0.000\\[3pt]\quad \text{Stability ratio} &:\quad \alpha := \varepsilon_{\text{triv}}/(1-\delta) = 0.211\\[3pt]\quad \text{Cocycle error} &:\quad \varepsilon_{\mathrm{coc}} := \sup_{(i\,j\,k)\in\mathcal{N}(\mathcal{U})}\left\|\Omega_{ij}\Omega_{jk}\Omega_{ki}-I\right\|_F = 0.000\end{aligned}$
# $\displaystyle \begin{aligned}\textbf{Characteristic Classes} & \\[6pt]\quad \text{Stiefel--Whitney} &:\quad w_1 = 0\ (\text{orientable})\\[3pt]\quad \text{Euler class} &:\quad e = 0\ (\text{trivial})\\[3pt]\quad \text{Euler rounding dist.} &:\quad d_\infty(\delta\theta, e) = 0\end{aligned}$
# <div style='height:12pt'></div>
# $\displaystyle \textbf{Class Persistence}$
# $\displaystyle \begin{array}{lrrrrr}\textbf{Stage} & k & r & |W_r^{(1)}| & |W_r^{(2)}| & |W_r^{(3)}| \\ \hline \text{Full nerve} & 0 & \infty & 30 & 0 & 0 \\ \text{w₁ cobirth} & 0 & \infty & 30 & 0 & 0 \\ \text{w₁ codeath} & 0 & \infty & 30 & 0 & 0 \\ \text{Euler cobirth} & 0 & \infty & 30 & 0 & 0 \\ \text{Euler codeath} & 0 & \infty & 30 & 0 & 0\end{array}$

# %%
app = cb.show_bundle_vis(base_points = base_points, data = data, colors = F)
